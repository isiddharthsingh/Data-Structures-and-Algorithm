# %%
def sum1(n):
    sum=0
    for x in range(n+1):
        sum += x
    return sum

# %%
sum1(10)
# Out:
# 55

# %%
def sum2(n):
    return (n*(n+1))/2

# %%
sum2(10)
# Out:
# 55.0

# %%
# %timeit sum1(100)
# Out:
# 3.81 µs ± 139 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit sum2(100)
# Out:
# 157 ns ± 18.5 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
from math import log
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

# Set up runtime comparisons
n = np.linspace(1,10,1000)
labels = ['Constant','Logarithmic','Linear','Log Linear','Quadratic','Cubic','Exponential']
big_o = [np.ones(n.shape),np.log(n),n,n*np.log(n),n**2,n**3,2**n]

# Plot setup
plt.figure(figsize=(12,10))
plt.ylim(0,50)

for i in range(len(big_o)):
    plt.plot(n,big_o[i],label = labels[i])


plt.legend(loc=0)
plt.ylabel('Relative Runtime')
plt.xlabel('n')
# Out:
# Text(0.5, 0, 'n')

# %% [markdown]
# # O(1) Constant

# %%
def func_constant(values):
    print(values[0])

# %%
func_constant([1,2,3,4])
# Out:
# 1

# %% [markdown]
# # O(n) Linear

# %%
def func_lin(lst):
    for val in lst:
        print(val)

# %%
lst=[1,2,3]
func_lin(lst)
# Out:
# 1
# 2
# 3

# %% [markdown]
# # O(n^2) Quadratic

# %%
def func_quad(lst):
    for item1 in lst:
        for item2 in lst:
            print(item1,item2)

# %%
func_quad(lst)
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3

# %%
def printonce(lst):#O(n)
    for val in lst:
        print(val)

# %%
printonce(lst)
# Out:
# 1
# 2
# 3

# %%
def print2(lst):#O(n)
    for val in lst:
        print(val)
    for val in lst:
        print(val)

# %%
print2(lst)
# Out:
# 1
# 2
# 3
# 1
# 2
# 3

# %%
def comp(lst):
    '''
    This function prints the first item O(1)
    Then is prints the first 1/2 of the list O(n/2)
    Then prints a string 10 times O(10)
    '''
    print (lst[0])
    
    midpoint = int(len(lst)/2)
    
    for val in (lst[:midpoint]):
        print (val)
        
    for x in range(10):
        print ('number')

# %%
lst=[1,2,3,4,5,6,7,8,9]
comp(lst)
# Out:
# 1
# 1
# 2
# 3
# 4
# number
# number
# number
# number
# number
# number
# number
# number
# number
# number

# %% [markdown]
# # O(1+n/2+10)
# # O(n)

# %%
def matcher(lst,match):
    for item in lst:
        if item == match:
            return True
    return False

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
matcher(lst,1) #O(1) best case as it is there at the starting index
# Out:
# True

# %%
matcher (lst,11) #O(n) worst case as it will check through all the list
# Out:
# False

# %% [markdown]
# # Space Complexity

# %%
def printer(n=10):
    '''
    Prints "hello world!" n times
    '''
    for x in range(n):
        print ('Hello World!')

# %%
printer()
# Out:
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!

# %%
def create_list(n):
    new_list = []
    
    for num in range(n):
        new_list.append('new')
    
    return new_list

# %%
create_list(5)
# Out:
# ['new', 'new', 'new', 'new', 'new']

# %%
def method1():
    l = []
    for n in range(10000):
        l = l + [n]

def method2():
    l = []
    for n in range(10000):
        l.append(n)

def method3():
    l = [n for n in range(10000)]

def method4():
    l = range(10000) # Python 3: list(range(10000))/

# %%
# %timeit method1()
# %timeit method2()
# %timeit method3()
# %timeit method4()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-090dc5e7af25> in <module>
# ----> 1 get_ipython().run_line_magic('timeit', 'method1()')
#       2 get_ipython().run_line_magic('timeit', 'method2()')
#       3 get_ipython().run_line_magic('timeit', 'method3()')
#       4 get_ipython().run_line_magic('timeit', 'method4()')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2311                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2312             with self.builtin_trap:
# -> 2313                 result = fn(*args, **kwargs)
#    2314             return result
#    2315
#
# <C:\ProgramData\Anaconda3\lib\site-packages\decorator.py:decorator-gen-61> in timeit(self, line, cell, local_ns)
#
# ...
